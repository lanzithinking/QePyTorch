# %% [markdown]
# # QEP Regression with Uncertain Inputs
#
# ## Introduction
#
# In this notebook, we're going to demonstrate one way of dealing with uncertainty in our training data. Let's say that we're collecting training data that models the following function.
#
# $$
# \begin{align}
# y &= \sin(2\pi x) + \epsilon \\
#   \epsilon &\sim \mathcal{Q}(0, 0.2)
# \end{align}
# $$
#
# However, now assume that we're a bit uncertain about our features. In particular, we're going to assume that every `x_i` value is not a point but a distribution instead. E.g.
#
# $$ x_i \sim \mathcal{Q}(\mu_i, \sigma_i). $$

# %% [markdown]
# ### Using a distributional kernel to deal with uncertain inputs
#
# Rather than using a variational method (see the QEP Regression with Uncertian Inputs tutorial in the variational examples), if we explicitly know the type of uncertainty in our inputs we can pass that into our kernel.
#
# More specifically, assuming Gaussian inputs, we will compute the symmetrized KL divergence between the Q-exponential inputs.

# %%
import math
import torch
import tqdm
import qpytorch
from matplotlib import pyplot as plt

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# [KeOps] Warning : There were warnings or errors :
# /bin/sh: brew: command not found
#
# [KeOps] Warning : CUDA libraries not found or could not be loaded; Switching to CPU only.
# [KeOps] Warning : OpenMP library 'libomp' not found.
# [KeOps] Warning : OpenMP support is not available. Disabling OpenMP.

# %%
# Training data is 100 points in [0,1] inclusive regularly spaced
train_x_mean = torch.linspace(0, 1, 20)
# We'll assume the variance shrinks the closer we get to 1
train_x_stdv = torch.linspace(0.03, 0.01, 20)

# True function is sin(2*pi*x) with Gaussian noise
train_y = torch.sin(train_x_mean * (2 * math.pi)) + torch.randn(train_x_mean.size()) * 0.2

# %% [markdown]
# To effectively pass in the training distributional data, we will need to stack the mean and log variances.

# %%
train_x_distributional = torch.stack((train_x_mean, (train_x_stdv**2).log()), dim=1)

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 3))
ax.errorbar(train_x_mean, train_y, xerr=(train_x_stdv * 2), fmt="k*", label="Train Data")
ax.legend()

# %% [markdown]
# We train the hyperparameters of the resulting distributional GP via type-II gradient descent, as is standard in many settings. We could also do fully Bayesian inference.

# %%
from qpytorch.models import ExactQEP
from qpytorch.kernels import QExponentialSymmetrizedKLKernel, ScaleKernel
from qpytorch.means import ConstantMean
POWER =1.0

class ExactQEPModel(ExactQEP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactQEPModel, self).__init__(train_x, train_y, likelihood)
        self.power = torch.tensor(POWER)
        self.mean_module = ConstantMean()
        self.covar_module = ScaleKernel(QExponentialSymmetrizedKLKernel())
        
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return qpytorch.distributions.MultivariateQExponential(mean_x, covar_x, power=self.power)

# initialize likelihood and model
likelihood = qpytorch.likelihoods.QExponentialLikelihood(power=torch.tensor(POWER))
model = ExactQEPModel(train_x_distributional, train_y, likelihood)

# %%
# this is for running the notebook in our testing framework
import os
smoke_test = ('CI' in os.environ)
training_iter = 2 if smoke_test else 500


# Find optimal model hyperparameters
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.25)  # Includes QExponentialLikelihood parameters

# "Loss" for QEPs - the marginal log likelihood
mll = qpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x_distributional)
    # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Iter 1/500 - Loss: 1.644   lengthscale: 0.693   noise: 0.693
# Iter 2/500 - Loss: 1.627   lengthscale: 0.826   noise: 0.576
# Iter 3/500 - Loss: 1.553   lengthscale: 0.968   noise: 0.474
# Iter 4/500 - Loss: 1.510   lengthscale: 1.127   noise: 0.387
# Iter 5/500 - Loss: 1.466   lengthscale: 1.301   noise: 0.313
# Iter 6/500 - Loss: 1.404   lengthscale: 1.488   noise: 0.251
# Iter 7/500 - Loss: 1.339   lengthscale: 1.688   noise: 0.200
# Iter 8/500 - Loss: 1.283   lengthscale: 1.899   noise: 0.159
# Iter 9/500 - Loss: 1.233   lengthscale: 2.120   noise: 0.125
# Iter 10/500 - Loss: 1.177   lengthscale: 2.350   noise: 0.098
# Iter 11/500 - Loss: 1.117   lengthscale: 2.588   noise: 0.077
# Iter 12/500 - Loss: 1.060   lengthscale: 2.832   noise: 0.060
# Iter 13/500 - Loss: 1.009   lengthscale: 3.080   noise: 0.046
# Iter 14/500 - Loss: 0.962   lengthscale: 3.333   noise: 0.036
# Iter 15/500 - Loss: 0.914   lengthscale: 3.588   noise: 0.028
# Iter 16/500 - Loss: 0.865   lengthscale: 3.845   noise: 0.021
# Iter 17/500 - Loss: 0.819   lengthscale: 4.103   noise: 0.017
# Iter 18/500 - Loss: 0.778   lengthscale: 4.362   noise: 0.013
# Iter 19/500 - Loss: 0.741   lengthscale: 4.621   noise: 0.010
# Iter 20/500 - Loss: 0.705   lengthscale: 4.879   noise: 0.008
# Iter 21/500 - Loss: 0.669   lengthscale: 5.137   noise: 0.006
# Iter 22/500 - Loss: 0.637   lengthscale: 5.392   noise: 0.005
# Iter 23/500 - Loss: 0.611   lengthscale: 5.646   noise: 0.004
# Iter 24/500 - Loss: 0.588   lengthscale: 5.897   noise: 0.003
# Iter 25/500 - Loss: 0.569   lengthscale: 6.145   noise: 0.002
# Iter 26/500 - Loss: 0.551   lengthscale: 6.389   noise: 0.002
# Iter 27/500 - Loss: 0.536   lengthscale: 6.628   noise: 0.002
# Iter 28/500 - Loss: 0.524   lengthscale: 6.862   noise: 0.001
# Iter 29/500 - Loss: 0.515   lengthscale: 7.090   noise: 0.001
# Iter 30/500 - Loss: 0.507   lengthscale: 7.312   noise: 0.001
# Iter 31/500 - Loss: 0.500   lengthscale: 7.528   noise: 0.001
# Iter 32/500 - Loss: 0.494   lengthscale: 7.736   noise: 0.001
# Iter 33/500 - Loss: 0.489   lengthscale: 7.938   noise: 0.001
# Iter 34/500 - Loss: 0.486   lengthscale: 8.132   noise: 0.001
# Iter 35/500 - Loss: 0.483   lengthscale: 8.319   noise: 0.001
# Iter 36/500 - Loss: 0.480   lengthscale: 8.499   noise: 0.000
# Iter 37/500 - Loss: 0.478   lengthscale: 8.671   noise: 0.000
# Iter 38/500 - Loss: 0.476   lengthscale: 8.836   noise: 0.000
# Iter 39/500 - Loss: 0.474   lengthscale: 8.995   noise: 0.000
# Iter 40/500 - Loss: 0.473   lengthscale: 9.146   noise: 0.000
# Iter 41/500 - Loss: 0.471   lengthscale: 9.290   noise: 0.000
# Iter 42/500 - Loss: 0.470   lengthscale: 9.428   noise: 0.000
# Iter 43/500 - Loss: 0.469   lengthscale: 9.560   noise: 0.000
# Iter 44/500 - Loss: 0.468   lengthscale: 9.685   noise: 0.000
# Iter 45/500 - Loss: 0.467   lengthscale: 9.805   noise: 0.000
# Iter 46/500 - Loss: 0.466   lengthscale: 9.920   noise: 0.000
# Iter 47/500 - Loss: 0.466   lengthscale: 10.029   noise: 0.000
# Iter 48/500 - Loss: 0.465   lengthscale: 10.134   noise: 0.000
# Iter 49/500 - Loss: 0.465   lengthscale: 10.234   noise: 0.000
# Iter 50/500 - Loss: 0.464   lengthscale: 10.330   noise: 0.000
# Iter 51/500 - Loss: 0.464   lengthscale: 10.422   noise: 0.000
# Iter 52/500 - Loss: 0.463   lengthscale: 10.510   noise: 0.000
# Iter 53/500 - Loss: 0.463   lengthscale: 10.595   noise: 0.000
# Iter 54/500 - Loss: 0.462   lengthscale: 10.675   noise: 0.000
# Iter 55/500 - Loss: 0.462   lengthscale: 10.753   noise: 0.000
# Iter 56/500 - Loss: 0.462   lengthscale: 10.827   noise: 0.000
# Iter 57/500 - Loss: 0.461   lengthscale: 10.898   noise: 0.000
# Iter 58/500 - Loss: 0.461   lengthscale: 10.966   noise: 0.000
# Iter 59/500 - Loss: 0.461   lengthscale: 11.031   noise: 0.000
# Iter 60/500 - Loss: 0.461   lengthscale: 11.094   noise: 0.000
# Iter 61/500 - Loss: 0.460   lengthscale: 11.155   noise: 0.000
# Iter 62/500 - Loss: 0.460   lengthscale: 11.213   noise: 0.000
# Iter 63/500 - Loss: 0.460   lengthscale: 11.269   noise: 0.000
# Iter 64/500 - Loss: 0.460   lengthscale: 11.323   noise: 0.000
# Iter 65/500 - Loss: 0.459   lengthscale: 11.375   noise: 0.000
# Iter 66/500 - Loss: 0.459   lengthscale: 11.426   noise: 0.000
# Iter 67/500 - Loss: 0.459   lengthscale: 11.475   noise: 0.000
# Iter 68/500 - Loss: 0.459   lengthscale: 11.523   noise: 0.000
# Iter 69/500 - Loss: 0.458   lengthscale: 11.570   noise: 0.000
# Iter 70/500 - Loss: 0.458   lengthscale: 11.615   noise: 0.000
# Iter 71/500 - Loss: 0.458   lengthscale: 11.659   noise: 0.000
# Iter 72/500 - Loss: 0.458   lengthscale: 11.702   noise: 0.000
# Iter 73/500 - Loss: 0.458   lengthscale: 11.744   noise: 0.000
# Iter 74/500 - Loss: 0.457   lengthscale: 11.785   noise: 0.000
# Iter 75/500 - Loss: 0.457   lengthscale: 11.826   noise: 0.000
# Iter 76/500 - Loss: 0.457   lengthscale: 11.865   noise: 0.000
# Iter 77/500 - Loss: 0.457   lengthscale: 11.904   noise: 0.000
# Iter 78/500 - Loss: 0.456   lengthscale: 11.942   noise: 0.000
# Iter 79/500 - Loss: 0.456   lengthscale: 11.979   noise: 0.000
# Iter 80/500 - Loss: 0.456   lengthscale: 12.015   noise: 0.000
# Iter 81/500 - Loss: 0.456   lengthscale: 12.051   noise: 0.000
# Iter 82/500 - Loss: 0.455   lengthscale: 12.086   noise: 0.000
# Iter 83/500 - Loss: 0.455   lengthscale: 12.121   noise: 0.000
# Iter 84/500 - Loss: 0.455   lengthscale: 12.155   noise: 0.000
# Iter 85/500 - Loss: 0.455   lengthscale: 12.189   noise: 0.000
# Iter 86/500 - Loss: 0.454   lengthscale: 12.223   noise: 0.000
# Iter 87/500 - Loss: 0.454   lengthscale: 12.256   noise: 0.000
# Iter 88/500 - Loss: 0.454   lengthscale: 12.289   noise: 0.000
# Iter 89/500 - Loss: 0.454   lengthscale: 12.322   noise: 0.000
# Iter 90/500 - Loss: 0.453   lengthscale: 12.355   noise: 0.000
# Iter 91/500 - Loss: 0.453   lengthscale: 12.387   noise: 0.000
# Iter 92/500 - Loss: 0.453   lengthscale: 12.419   noise: 0.000
# Iter 93/500 - Loss: 0.452   lengthscale: 12.451   noise: 0.000
# Iter 94/500 - Loss: 0.452   lengthscale: 12.483   noise: 0.000
# Iter 95/500 - Loss: 0.452   lengthscale: 12.515   noise: 0.000
# Iter 96/500 - Loss: 0.452   lengthscale: 12.547   noise: 0.000
# Iter 97/500 - Loss: 0.451   lengthscale: 12.578   noise: 0.000
# Iter 98/500 - Loss: 0.451   lengthscale: 12.610   noise: 0.000
# Iter 99/500 - Loss: 0.451   lengthscale: 12.641   noise: 0.000
# Iter 100/500 - Loss: 0.450   lengthscale: 12.673   noise: 0.000
# Iter 101/500 - Loss: 0.450   lengthscale: 12.704   noise: 0.000
# Iter 102/500 - Loss: 0.450   lengthscale: 12.736   noise: 0.000
# Iter 103/500 - Loss: 0.450   lengthscale: 12.768   noise: 0.001
# Iter 104/500 - Loss: 0.449   lengthscale: 12.799   noise: 0.001
# Iter 105/500 - Loss: 0.449   lengthscale: 12.831   noise: 0.001
# Iter 106/500 - Loss: 0.449   lengthscale: 12.863   noise: 0.001
# Iter 107/500 - Loss: 0.448   lengthscale: 12.895   noise: 0.001
# Iter 108/500 - Loss: 0.448   lengthscale: 12.928   noise: 0.001
# Iter 109/500 - Loss: 0.448   lengthscale: 12.960   noise: 0.001
# Iter 110/500 - Loss: 0.448   lengthscale: 12.992   noise: 0.001
# Iter 111/500 - Loss: 0.447   lengthscale: 13.025   noise: 0.001
# Iter 112/500 - Loss: 0.447   lengthscale: 13.058   noise: 0.001
# Iter 113/500 - Loss: 0.447   lengthscale: 13.091   noise: 0.001
# Iter 114/500 - Loss: 0.447   lengthscale: 13.124   noise: 0.001
# Iter 115/500 - Loss: 0.447   lengthscale: 13.157   noise: 0.001
# Iter 116/500 - Loss: 0.446   lengthscale: 13.191   noise: 0.001
# Iter 117/500 - Loss: 0.446   lengthscale: 13.224   noise: 0.001
# Iter 118/500 - Loss: 0.446   lengthscale: 13.258   noise: 0.001
# Iter 119/500 - Loss: 0.446   lengthscale: 13.292   noise: 0.001
# Iter 120/500 - Loss: 0.446   lengthscale: 13.325   noise: 0.001
# Iter 121/500 - Loss: 0.446   lengthscale: 13.360   noise: 0.001
# Iter 122/500 - Loss: 0.446   lengthscale: 13.394   noise: 0.001
# Iter 123/500 - Loss: 0.446   lengthscale: 13.428   noise: 0.001
# Iter 124/500 - Loss: 0.446   lengthscale: 13.462   noise: 0.001
# Iter 125/500 - Loss: 0.445   lengthscale: 13.497   noise: 0.001
# Iter 126/500 - Loss: 0.445   lengthscale: 13.531   noise: 0.001
# Iter 127/500 - Loss: 0.445   lengthscale: 13.566   noise: 0.001
# Iter 128/500 - Loss: 0.445   lengthscale: 13.600   noise: 0.001
# Iter 129/500 - Loss: 0.445   lengthscale: 13.635   noise: 0.001
# Iter 130/500 - Loss: 0.445   lengthscale: 13.669   noise: 0.001
# Iter 131/500 - Loss: 0.445   lengthscale: 13.704   noise: 0.001
# Iter 132/500 - Loss: 0.445   lengthscale: 13.738   noise: 0.001
# Iter 133/500 - Loss: 0.445   lengthscale: 13.772   noise: 0.001
# Iter 134/500 - Loss: 0.445   lengthscale: 13.806   noise: 0.001
# Iter 135/500 - Loss: 0.445   lengthscale: 13.841   noise: 0.001
# Iter 136/500 - Loss: 0.444   lengthscale: 13.874   noise: 0.001
# Iter 137/500 - Loss: 0.444   lengthscale: 13.908   noise: 0.001
# Iter 138/500 - Loss: 0.444   lengthscale: 13.942   noise: 0.001
# Iter 139/500 - Loss: 0.444   lengthscale: 13.975   noise: 0.001
# Iter 140/500 - Loss: 0.444   lengthscale: 14.008   noise: 0.001
# Iter 141/500 - Loss: 0.444   lengthscale: 14.041   noise: 0.001
# Iter 142/500 - Loss: 0.444   lengthscale: 14.074   noise: 0.001
# Iter 143/500 - Loss: 0.444   lengthscale: 14.107   noise: 0.001
# Iter 144/500 - Loss: 0.444   lengthscale: 14.139   noise: 0.001
# Iter 145/500 - Loss: 0.444   lengthscale: 14.171   noise: 0.001
# Iter 146/500 - Loss: 0.444   lengthscale: 14.203   noise: 0.001
# Iter 147/500 - Loss: 0.444   lengthscale: 14.234   noise: 0.001
# Iter 148/500 - Loss: 0.444   lengthscale: 14.265   noise: 0.001
# Iter 149/500 - Loss: 0.444   lengthscale: 14.296   noise: 0.001
# Iter 150/500 - Loss: 0.443   lengthscale: 14.327   noise: 0.001
# Iter 151/500 - Loss: 0.443   lengthscale: 14.357   noise: 0.001
# Iter 152/500 - Loss: 0.443   lengthscale: 14.387   noise: 0.001
# Iter 153/500 - Loss: 0.443   lengthscale: 14.417   noise: 0.001
# Iter 154/500 - Loss: 0.443   lengthscale: 14.447   noise: 0.001
# Iter 155/500 - Loss: 0.443   lengthscale: 14.476   noise: 0.001
# Iter 156/500 - Loss: 0.443   lengthscale: 14.505   noise: 0.001
# Iter 157/500 - Loss: 0.443   lengthscale: 14.533   noise: 0.001
# Iter 158/500 - Loss: 0.443   lengthscale: 14.562   noise: 0.001
# Iter 159/500 - Loss: 0.443   lengthscale: 14.590   noise: 0.001
# Iter 160/500 - Loss: 0.443   lengthscale: 14.618   noise: 0.001
# Iter 161/500 - Loss: 0.443   lengthscale: 14.645   noise: 0.001
# Iter 162/500 - Loss: 0.443   lengthscale: 14.673   noise: 0.001
# Iter 163/500 - Loss: 0.443   lengthscale: 14.700   noise: 0.001
# Iter 164/500 - Loss: 0.443   lengthscale: 14.727   noise: 0.001
# Iter 165/500 - Loss: 0.443   lengthscale: 14.753   noise: 0.001
# Iter 166/500 - Loss: 0.443   lengthscale: 14.779   noise: 0.001
# Iter 167/500 - Loss: 0.443   lengthscale: 14.806   noise: 0.001
# Iter 168/500 - Loss: 0.443   lengthscale: 14.831   noise: 0.001
# Iter 169/500 - Loss: 0.443   lengthscale: 14.857   noise: 0.001
# Iter 170/500 - Loss: 0.442   lengthscale: 14.882   noise: 0.001
# Iter 171/500 - Loss: 0.442   lengthscale: 14.908   noise: 0.001
# Iter 172/500 - Loss: 0.442   lengthscale: 14.933   noise: 0.001
# Iter 173/500 - Loss: 0.442   lengthscale: 14.958   noise: 0.001
# Iter 174/500 - Loss: 0.442   lengthscale: 14.982   noise: 0.001
# Iter 175/500 - Loss: 0.442   lengthscale: 15.007   noise: 0.001
# Iter 176/500 - Loss: 0.442   lengthscale: 15.031   noise: 0.001
# Iter 177/500 - Loss: 0.442   lengthscale: 15.055   noise: 0.001
# Iter 178/500 - Loss: 0.442   lengthscale: 15.079   noise: 0.001
# Iter 179/500 - Loss: 0.442   lengthscale: 15.102   noise: 0.001
# Iter 180/500 - Loss: 0.442   lengthscale: 15.126   noise: 0.001
# Iter 181/500 - Loss: 0.442   lengthscale: 15.149   noise: 0.001
# Iter 182/500 - Loss: 0.442   lengthscale: 15.172   noise: 0.001
# Iter 183/500 - Loss: 0.442   lengthscale: 15.195   noise: 0.001
# Iter 184/500 - Loss: 0.442   lengthscale: 15.218   noise: 0.001
# Iter 185/500 - Loss: 0.442   lengthscale: 15.241   noise: 0.001
# Iter 186/500 - Loss: 0.442   lengthscale: 15.263   noise: 0.001
# Iter 187/500 - Loss: 0.442   lengthscale: 15.286   noise: 0.001
# Iter 188/500 - Loss: 0.442   lengthscale: 15.308   noise: 0.001
# Iter 189/500 - Loss: 0.442   lengthscale: 15.330   noise: 0.001
# Iter 190/500 - Loss: 0.442   lengthscale: 15.352   noise: 0.001
# Iter 191/500 - Loss: 0.442   lengthscale: 15.373   noise: 0.001
# Iter 192/500 - Loss: 0.442   lengthscale: 15.395   noise: 0.001
# Iter 193/500 - Loss: 0.442   lengthscale: 15.416   noise: 0.001
# Iter 194/500 - Loss: 0.442   lengthscale: 15.437   noise: 0.001
# Iter 195/500 - Loss: 0.442   lengthscale: 15.458   noise: 0.001
# Iter 196/500 - Loss: 0.442   lengthscale: 15.479   noise: 0.001
# Iter 197/500 - Loss: 0.442   lengthscale: 15.500   noise: 0.001
# Iter 198/500 - Loss: 0.442   lengthscale: 15.521   noise: 0.001
# Iter 199/500 - Loss: 0.442   lengthscale: 15.541   noise: 0.001
# Iter 200/500 - Loss: 0.442   lengthscale: 15.561   noise: 0.001
# Iter 201/500 - Loss: 0.442   lengthscale: 15.581   noise: 0.001
# Iter 202/500 - Loss: 0.442   lengthscale: 15.601   noise: 0.001
# Iter 203/500 - Loss: 0.441   lengthscale: 15.621   noise: 0.001
# Iter 204/500 - Loss: 0.441   lengthscale: 15.641   noise: 0.001
# Iter 205/500 - Loss: 0.441   lengthscale: 15.660   noise: 0.001
# Iter 206/500 - Loss: 0.441   lengthscale: 15.680   noise: 0.001
# Iter 207/500 - Loss: 0.441   lengthscale: 15.699   noise: 0.001
# Iter 208/500 - Loss: 0.441   lengthscale: 15.718   noise: 0.001
# Iter 209/500 - Loss: 0.441   lengthscale: 15.737   noise: 0.001
# Iter 210/500 - Loss: 0.441   lengthscale: 15.756   noise: 0.001
# Iter 211/500 - Loss: 0.441   lengthscale: 15.774   noise: 0.001
# Iter 212/500 - Loss: 0.441   lengthscale: 15.793   noise: 0.001
# Iter 213/500 - Loss: 0.441   lengthscale: 15.811   noise: 0.001
# Iter 214/500 - Loss: 0.441   lengthscale: 15.830   noise: 0.001
# Iter 215/500 - Loss: 0.441   lengthscale: 15.848   noise: 0.001
# Iter 216/500 - Loss: 0.441   lengthscale: 15.866   noise: 0.001
# Iter 217/500 - Loss: 0.441   lengthscale: 15.883   noise: 0.001
# Iter 218/500 - Loss: 0.441   lengthscale: 15.901   noise: 0.001
# Iter 219/500 - Loss: 0.441   lengthscale: 15.919   noise: 0.001
# Iter 220/500 - Loss: 0.441   lengthscale: 15.936   noise: 0.001
# Iter 221/500 - Loss: 0.441   lengthscale: 15.954   noise: 0.001
# Iter 222/500 - Loss: 0.441   lengthscale: 15.971   noise: 0.001
# Iter 223/500 - Loss: 0.441   lengthscale: 15.988   noise: 0.001
# Iter 224/500 - Loss: 0.441   lengthscale: 16.005   noise: 0.001
# Iter 225/500 - Loss: 0.441   lengthscale: 16.022   noise: 0.001
# Iter 226/500 - Loss: 0.441   lengthscale: 16.038   noise: 0.001
# Iter 227/500 - Loss: 0.441   lengthscale: 16.055   noise: 0.001
# Iter 228/500 - Loss: 0.441   lengthscale: 16.072   noise: 0.001
# Iter 229/500 - Loss: 0.441   lengthscale: 16.088   noise: 0.001
# Iter 230/500 - Loss: 0.441   lengthscale: 16.104   noise: 0.001
# Iter 231/500 - Loss: 0.441   lengthscale: 16.120   noise: 0.001
# Iter 232/500 - Loss: 0.441   lengthscale: 16.136   noise: 0.001
# Iter 233/500 - Loss: 0.441   lengthscale: 16.152   noise: 0.001
# Iter 234/500 - Loss: 0.441   lengthscale: 16.168   noise: 0.001
# Iter 235/500 - Loss: 0.441   lengthscale: 16.184   noise: 0.001
# Iter 236/500 - Loss: 0.441   lengthscale: 16.199   noise: 0.001
# Iter 237/500 - Loss: 0.441   lengthscale: 16.215   noise: 0.001
# Iter 238/500 - Loss: 0.441   lengthscale: 16.230   noise: 0.001
# Iter 239/500 - Loss: 0.441   lengthscale: 16.246   noise: 0.001
# Iter 240/500 - Loss: 0.441   lengthscale: 16.261   noise: 0.001
# Iter 241/500 - Loss: 0.441   lengthscale: 16.276   noise: 0.001
# Iter 242/500 - Loss: 0.441   lengthscale: 16.291   noise: 0.001
# Iter 243/500 - Loss: 0.441   lengthscale: 16.306   noise: 0.001
# Iter 244/500 - Loss: 0.441   lengthscale: 16.320   noise: 0.001
# Iter 245/500 - Loss: 0.441   lengthscale: 16.335   noise: 0.001
# Iter 246/500 - Loss: 0.441   lengthscale: 16.350   noise: 0.001
# Iter 247/500 - Loss: 0.441   lengthscale: 16.364   noise: 0.001
# Iter 248/500 - Loss: 0.441   lengthscale: 16.379   noise: 0.001
# Iter 249/500 - Loss: 0.441   lengthscale: 16.393   noise: 0.001
# Iter 250/500 - Loss: 0.441   lengthscale: 16.407   noise: 0.001
# Iter 251/500 - Loss: 0.441   lengthscale: 16.421   noise: 0.001
# Iter 252/500 - Loss: 0.441   lengthscale: 16.435   noise: 0.001
# Iter 253/500 - Loss: 0.441   lengthscale: 16.449   noise: 0.001
# Iter 254/500 - Loss: 0.441   lengthscale: 16.463   noise: 0.001
# Iter 255/500 - Loss: 0.441   lengthscale: 16.476   noise: 0.001
# Iter 256/500 - Loss: 0.441   lengthscale: 16.490   noise: 0.001
# Iter 257/500 - Loss: 0.441   lengthscale: 16.503   noise: 0.001
# Iter 258/500 - Loss: 0.441   lengthscale: 16.517   noise: 0.001
# Iter 259/500 - Loss: 0.441   lengthscale: 16.530   noise: 0.001
# Iter 260/500 - Loss: 0.441   lengthscale: 16.543   noise: 0.001
# Iter 261/500 - Loss: 0.441   lengthscale: 16.556   noise: 0.001
# Iter 262/500 - Loss: 0.441   lengthscale: 16.570   noise: 0.001
# Iter 263/500 - Loss: 0.441   lengthscale: 16.582   noise: 0.001
# Iter 264/500 - Loss: 0.441   lengthscale: 16.595   noise: 0.001
# Iter 265/500 - Loss: 0.441   lengthscale: 16.608   noise: 0.001
# Iter 266/500 - Loss: 0.441   lengthscale: 16.621   noise: 0.001
# Iter 267/500 - Loss: 0.441   lengthscale: 16.633   noise: 0.001
# Iter 268/500 - Loss: 0.441   lengthscale: 16.646   noise: 0.001
# Iter 269/500 - Loss: 0.441   lengthscale: 16.658   noise: 0.001
# Iter 270/500 - Loss: 0.441   lengthscale: 16.671   noise: 0.001
# Iter 271/500 - Loss: 0.441   lengthscale: 16.683   noise: 0.001
# Iter 272/500 - Loss: 0.441   lengthscale: 16.695   noise: 0.001
# Iter 273/500 - Loss: 0.441   lengthscale: 16.707   noise: 0.001
# Iter 274/500 - Loss: 0.441   lengthscale: 16.719   noise: 0.001
# Iter 275/500 - Loss: 0.441   lengthscale: 16.731   noise: 0.001
# Iter 276/500 - Loss: 0.441   lengthscale: 16.743   noise: 0.001
# Iter 277/500 - Loss: 0.441   lengthscale: 16.755   noise: 0.001
# Iter 278/500 - Loss: 0.441   lengthscale: 16.767   noise: 0.001
# Iter 279/500 - Loss: 0.441   lengthscale: 16.778   noise: 0.001
# Iter 280/500 - Loss: 0.441   lengthscale: 16.790   noise: 0.001
# Iter 281/500 - Loss: 0.441   lengthscale: 16.801   noise: 0.001
# Iter 282/500 - Loss: 0.441   lengthscale: 16.813   noise: 0.001
# Iter 283/500 - Loss: 0.440   lengthscale: 16.824   noise: 0.001
# Iter 284/500 - Loss: 0.440   lengthscale: 16.835   noise: 0.001
# Iter 285/500 - Loss: 0.440   lengthscale: 16.846   noise: 0.001
# Iter 286/500 - Loss: 0.440   lengthscale: 16.858   noise: 0.001
# Iter 287/500 - Loss: 0.440   lengthscale: 16.869   noise: 0.001
# Iter 288/500 - Loss: 0.440   lengthscale: 16.879   noise: 0.001
# Iter 289/500 - Loss: 0.440   lengthscale: 16.890   noise: 0.001
# Iter 290/500 - Loss: 0.440   lengthscale: 16.901   noise: 0.001
# Iter 291/500 - Loss: 0.440   lengthscale: 16.912   noise: 0.001
# Iter 292/500 - Loss: 0.440   lengthscale: 16.923   noise: 0.001
# Iter 293/500 - Loss: 0.440   lengthscale: 16.933   noise: 0.001
# Iter 294/500 - Loss: 0.440   lengthscale: 16.944   noise: 0.001
# Iter 295/500 - Loss: 0.440   lengthscale: 16.954   noise: 0.001
# Iter 296/500 - Loss: 0.440   lengthscale: 16.964   noise: 0.001
# Iter 297/500 - Loss: 0.440   lengthscale: 16.975   noise: 0.001
# Iter 298/500 - Loss: 0.440   lengthscale: 16.985   noise: 0.001
# Iter 299/500 - Loss: 0.440   lengthscale: 16.995   noise: 0.001
# Iter 300/500 - Loss: 0.440   lengthscale: 17.005   noise: 0.001
# Iter 301/500 - Loss: 0.440   lengthscale: 17.015   noise: 0.001
# Iter 302/500 - Loss: 0.440   lengthscale: 17.025   noise: 0.001
# Iter 303/500 - Loss: 0.440   lengthscale: 17.035   noise: 0.001
# Iter 304/500 - Loss: 0.440   lengthscale: 17.045   noise: 0.001
# Iter 305/500 - Loss: 0.440   lengthscale: 17.055   noise: 0.001
# Iter 306/500 - Loss: 0.440   lengthscale: 17.064   noise: 0.001
# Iter 307/500 - Loss: 0.440   lengthscale: 17.074   noise: 0.001
# Iter 308/500 - Loss: 0.440   lengthscale: 17.084   noise: 0.001
# Iter 309/500 - Loss: 0.440   lengthscale: 17.093   noise: 0.001
# Iter 310/500 - Loss: 0.440   lengthscale: 17.103   noise: 0.001
# Iter 311/500 - Loss: 0.440   lengthscale: 17.112   noise: 0.001
# Iter 312/500 - Loss: 0.440   lengthscale: 17.121   noise: 0.001
# Iter 313/500 - Loss: 0.440   lengthscale: 17.131   noise: 0.001
# Iter 314/500 - Loss: 0.440   lengthscale: 17.140   noise: 0.001
# Iter 315/500 - Loss: 0.440   lengthscale: 17.149   noise: 0.001
# Iter 316/500 - Loss: 0.440   lengthscale: 17.158   noise: 0.001
# Iter 317/500 - Loss: 0.440   lengthscale: 17.167   noise: 0.001
# Iter 318/500 - Loss: 0.440   lengthscale: 17.176   noise: 0.001
# Iter 319/500 - Loss: 0.440   lengthscale: 17.185   noise: 0.001
# Iter 320/500 - Loss: 0.440   lengthscale: 17.194   noise: 0.001
# Iter 321/500 - Loss: 0.440   lengthscale: 17.203   noise: 0.001
# Iter 322/500 - Loss: 0.440   lengthscale: 17.211   noise: 0.001
# Iter 323/500 - Loss: 0.440   lengthscale: 17.220   noise: 0.001
# Iter 324/500 - Loss: 0.440   lengthscale: 17.229   noise: 0.001
# Iter 325/500 - Loss: 0.440   lengthscale: 17.237   noise: 0.001
# Iter 326/500 - Loss: 0.440   lengthscale: 17.246   noise: 0.001
# Iter 327/500 - Loss: 0.440   lengthscale: 17.254   noise: 0.001
# Iter 328/500 - Loss: 0.440   lengthscale: 17.262   noise: 0.001
# Iter 329/500 - Loss: 0.440   lengthscale: 17.271   noise: 0.001
# Iter 330/500 - Loss: 0.440   lengthscale: 17.279   noise: 0.001
# Iter 331/500 - Loss: 0.440   lengthscale: 17.287   noise: 0.001
# Iter 332/500 - Loss: 0.440   lengthscale: 17.295   noise: 0.001
# Iter 333/500 - Loss: 0.440   lengthscale: 17.304   noise: 0.001
# Iter 334/500 - Loss: 0.440   lengthscale: 17.312   noise: 0.001
# Iter 335/500 - Loss: 0.440   lengthscale: 17.320   noise: 0.001
# Iter 336/500 - Loss: 0.440   lengthscale: 17.328   noise: 0.001
# Iter 337/500 - Loss: 0.440   lengthscale: 17.335   noise: 0.001
# Iter 338/500 - Loss: 0.440   lengthscale: 17.343   noise: 0.001
# Iter 339/500 - Loss: 0.440   lengthscale: 17.351   noise: 0.001
# Iter 340/500 - Loss: 0.440   lengthscale: 17.359   noise: 0.001
# Iter 341/500 - Loss: 0.440   lengthscale: 17.366   noise: 0.001
# Iter 342/500 - Loss: 0.440   lengthscale: 17.374   noise: 0.001
# Iter 343/500 - Loss: 0.440   lengthscale: 17.382   noise: 0.001
# Iter 344/500 - Loss: 0.440   lengthscale: 17.389   noise: 0.001
# Iter 345/500 - Loss: 0.440   lengthscale: 17.397   noise: 0.001
# Iter 346/500 - Loss: 0.440   lengthscale: 17.404   noise: 0.001
# Iter 347/500 - Loss: 0.440   lengthscale: 17.412   noise: 0.001
# Iter 348/500 - Loss: 0.440   lengthscale: 17.419   noise: 0.001
# Iter 349/500 - Loss: 0.440   lengthscale: 17.426   noise: 0.001
# Iter 350/500 - Loss: 0.440   lengthscale: 17.433   noise: 0.001
# Iter 351/500 - Loss: 0.440   lengthscale: 17.441   noise: 0.001
# Iter 352/500 - Loss: 0.440   lengthscale: 17.448   noise: 0.001
# Iter 353/500 - Loss: 0.440   lengthscale: 17.455   noise: 0.001
# Iter 354/500 - Loss: 0.440   lengthscale: 17.462   noise: 0.001
# Iter 355/500 - Loss: 0.440   lengthscale: 17.469   noise: 0.001
# Iter 356/500 - Loss: 0.440   lengthscale: 17.476   noise: 0.001
# Iter 357/500 - Loss: 0.440   lengthscale: 17.483   noise: 0.001
# Iter 358/500 - Loss: 0.440   lengthscale: 17.490   noise: 0.001
# Iter 359/500 - Loss: 0.440   lengthscale: 17.496   noise: 0.001
# Iter 360/500 - Loss: 0.440   lengthscale: 17.503   noise: 0.001
# Iter 361/500 - Loss: 0.440   lengthscale: 17.510   noise: 0.001
# Iter 362/500 - Loss: 0.440   lengthscale: 17.517   noise: 0.001
# Iter 363/500 - Loss: 0.440   lengthscale: 17.523   noise: 0.001
# Iter 364/500 - Loss: 0.440   lengthscale: 17.530   noise: 0.001
# Iter 365/500 - Loss: 0.440   lengthscale: 17.536   noise: 0.001
# Iter 366/500 - Loss: 0.440   lengthscale: 17.543   noise: 0.001
# Iter 367/500 - Loss: 0.440   lengthscale: 17.549   noise: 0.001
# Iter 368/500 - Loss: 0.440   lengthscale: 17.556   noise: 0.001
# Iter 369/500 - Loss: 0.440   lengthscale: 17.562   noise: 0.001
# Iter 370/500 - Loss: 0.440   lengthscale: 17.568   noise: 0.001
# Iter 371/500 - Loss: 0.440   lengthscale: 17.575   noise: 0.001
# Iter 372/500 - Loss: 0.440   lengthscale: 17.581   noise: 0.001
# Iter 373/500 - Loss: 0.440   lengthscale: 17.587   noise: 0.001
# Iter 374/500 - Loss: 0.440   lengthscale: 17.593   noise: 0.001
# Iter 375/500 - Loss: 0.440   lengthscale: 17.599   noise: 0.001
# Iter 376/500 - Loss: 0.440   lengthscale: 17.605   noise: 0.001
# Iter 377/500 - Loss: 0.440   lengthscale: 17.611   noise: 0.001
# Iter 378/500 - Loss: 0.440   lengthscale: 17.617   noise: 0.001
# Iter 379/500 - Loss: 0.440   lengthscale: 17.623   noise: 0.001
# Iter 380/500 - Loss: 0.440   lengthscale: 17.629   noise: 0.001
# Iter 381/500 - Loss: 0.440   lengthscale: 17.635   noise: 0.001
# Iter 382/500 - Loss: 0.440   lengthscale: 17.641   noise: 0.001
# Iter 383/500 - Loss: 0.440   lengthscale: 17.647   noise: 0.001
# Iter 384/500 - Loss: 0.440   lengthscale: 17.653   noise: 0.001
# Iter 385/500 - Loss: 0.440   lengthscale: 17.658   noise: 0.001
# Iter 386/500 - Loss: 0.440   lengthscale: 17.664   noise: 0.001
# Iter 387/500 - Loss: 0.440   lengthscale: 17.670   noise: 0.001
# Iter 388/500 - Loss: 0.440   lengthscale: 17.675   noise: 0.001
# Iter 389/500 - Loss: 0.440   lengthscale: 17.681   noise: 0.001
# Iter 390/500 - Loss: 0.440   lengthscale: 17.686   noise: 0.001
# Iter 391/500 - Loss: 0.440   lengthscale: 17.692   noise: 0.001
# Iter 392/500 - Loss: 0.440   lengthscale: 17.697   noise: 0.001
# Iter 393/500 - Loss: 0.440   lengthscale: 17.703   noise: 0.001
# Iter 394/500 - Loss: 0.440   lengthscale: 17.708   noise: 0.001
# Iter 395/500 - Loss: 0.440   lengthscale: 17.713   noise: 0.001
# Iter 396/500 - Loss: 0.440   lengthscale: 17.719   noise: 0.001
# Iter 397/500 - Loss: 0.440   lengthscale: 17.724   noise: 0.001
# Iter 398/500 - Loss: 0.440   lengthscale: 17.729   noise: 0.001
# Iter 399/500 - Loss: 0.440   lengthscale: 17.734   noise: 0.001
# Iter 400/500 - Loss: 0.440   lengthscale: 17.739   noise: 0.001
# Iter 401/500 - Loss: 0.440   lengthscale: 17.745   noise: 0.001
# Iter 402/500 - Loss: 0.440   lengthscale: 17.750   noise: 0.001
# Iter 403/500 - Loss: 0.440   lengthscale: 17.755   noise: 0.001
# Iter 404/500 - Loss: 0.440   lengthscale: 17.760   noise: 0.001
# Iter 405/500 - Loss: 0.440   lengthscale: 17.765   noise: 0.001
# Iter 406/500 - Loss: 0.440   lengthscale: 17.770   noise: 0.001
# Iter 407/500 - Loss: 0.440   lengthscale: 17.775   noise: 0.001
# Iter 408/500 - Loss: 0.440   lengthscale: 17.779   noise: 0.001
# Iter 409/500 - Loss: 0.440   lengthscale: 17.784   noise: 0.001
# Iter 410/500 - Loss: 0.440   lengthscale: 17.789   noise: 0.001
# Iter 411/500 - Loss: 0.440   lengthscale: 17.794   noise: 0.001
# Iter 412/500 - Loss: 0.440   lengthscale: 17.799   noise: 0.001
# Iter 413/500 - Loss: 0.440   lengthscale: 17.803   noise: 0.001
# Iter 414/500 - Loss: 0.440   lengthscale: 17.808   noise: 0.001
# Iter 415/500 - Loss: 0.440   lengthscale: 17.813   noise: 0.001
# Iter 416/500 - Loss: 0.440   lengthscale: 17.817   noise: 0.001
# Iter 417/500 - Loss: 0.440   lengthscale: 17.822   noise: 0.001
# Iter 418/500 - Loss: 0.440   lengthscale: 17.826   noise: 0.001
# Iter 419/500 - Loss: 0.440   lengthscale: 17.831   noise: 0.001
# Iter 420/500 - Loss: 0.440   lengthscale: 17.835   noise: 0.001
# Iter 421/500 - Loss: 0.440   lengthscale: 17.840   noise: 0.001
# Iter 422/500 - Loss: 0.440   lengthscale: 17.844   noise: 0.001
# Iter 423/500 - Loss: 0.440   lengthscale: 17.849   noise: 0.001
# Iter 424/500 - Loss: 0.440   lengthscale: 17.853   noise: 0.001
# Iter 425/500 - Loss: 0.440   lengthscale: 17.857   noise: 0.001
# Iter 426/500 - Loss: 0.440   lengthscale: 17.862   noise: 0.001
# Iter 427/500 - Loss: 0.440   lengthscale: 17.866   noise: 0.001
# Iter 428/500 - Loss: 0.440   lengthscale: 17.870   noise: 0.001
# Iter 429/500 - Loss: 0.440   lengthscale: 17.874   noise: 0.001
# Iter 430/500 - Loss: 0.440   lengthscale: 17.879   noise: 0.001
# Iter 431/500 - Loss: 0.440   lengthscale: 17.883   noise: 0.001
# Iter 432/500 - Loss: 0.440   lengthscale: 17.887   noise: 0.001
# Iter 433/500 - Loss: 0.440   lengthscale: 17.891   noise: 0.001
# Iter 434/500 - Loss: 0.440   lengthscale: 17.895   noise: 0.001
# Iter 435/500 - Loss: 0.440   lengthscale: 17.899   noise: 0.001
# Iter 436/500 - Loss: 0.440   lengthscale: 17.903   noise: 0.001
# Iter 437/500 - Loss: 0.440   lengthscale: 17.907   noise: 0.001
# Iter 438/500 - Loss: 0.440   lengthscale: 17.911   noise: 0.001
# Iter 439/500 - Loss: 0.440   lengthscale: 17.915   noise: 0.001
# Iter 440/500 - Loss: 0.440   lengthscale: 17.919   noise: 0.001
# Iter 441/500 - Loss: 0.440   lengthscale: 17.923   noise: 0.001
# Iter 442/500 - Loss: 0.440   lengthscale: 17.927   noise: 0.001
# Iter 443/500 - Loss: 0.440   lengthscale: 17.930   noise: 0.001
# Iter 444/500 - Loss: 0.440   lengthscale: 17.934   noise: 0.001
# Iter 445/500 - Loss: 0.440   lengthscale: 17.938   noise: 0.001
# Iter 446/500 - Loss: 0.440   lengthscale: 17.942   noise: 0.001
# Iter 447/500 - Loss: 0.440   lengthscale: 17.945   noise: 0.001
# Iter 448/500 - Loss: 0.440   lengthscale: 17.949   noise: 0.001
# Iter 449/500 - Loss: 0.440   lengthscale: 17.953   noise: 0.001
# Iter 450/500 - Loss: 0.440   lengthscale: 17.956   noise: 0.001
# Iter 451/500 - Loss: 0.440   lengthscale: 17.960   noise: 0.001
# Iter 452/500 - Loss: 0.440   lengthscale: 17.964   noise: 0.001
# Iter 453/500 - Loss: 0.440   lengthscale: 17.967   noise: 0.001
# Iter 454/500 - Loss: 0.440   lengthscale: 17.971   noise: 0.001
# Iter 455/500 - Loss: 0.440   lengthscale: 17.974   noise: 0.001
# Iter 456/500 - Loss: 0.440   lengthscale: 17.978   noise: 0.001
# Iter 457/500 - Loss: 0.440   lengthscale: 17.981   noise: 0.001
# Iter 458/500 - Loss: 0.440   lengthscale: 17.985   noise: 0.001
# Iter 459/500 - Loss: 0.440   lengthscale: 17.988   noise: 0.001
# Iter 460/500 - Loss: 0.440   lengthscale: 17.991   noise: 0.001
# Iter 461/500 - Loss: 0.440   lengthscale: 17.995   noise: 0.001
# Iter 462/500 - Loss: 0.440   lengthscale: 17.998   noise: 0.001
# Iter 463/500 - Loss: 0.440   lengthscale: 18.001   noise: 0.001
# Iter 464/500 - Loss: 0.440   lengthscale: 18.005   noise: 0.001
# Iter 465/500 - Loss: 0.440   lengthscale: 18.008   noise: 0.001
# Iter 466/500 - Loss: 0.440   lengthscale: 18.011   noise: 0.001
# Iter 467/500 - Loss: 0.440   lengthscale: 18.014   noise: 0.001
# Iter 468/500 - Loss: 0.440   lengthscale: 18.018   noise: 0.001
# Iter 469/500 - Loss: 0.440   lengthscale: 18.021   noise: 0.001
# Iter 470/500 - Loss: 0.440   lengthscale: 18.024   noise: 0.001
# Iter 471/500 - Loss: 0.440   lengthscale: 18.027   noise: 0.001
# Iter 472/500 - Loss: 0.440   lengthscale: 18.030   noise: 0.001
# Iter 473/500 - Loss: 0.440   lengthscale: 18.033   noise: 0.001
# Iter 474/500 - Loss: 0.440   lengthscale: 18.036   noise: 0.001
# Iter 475/500 - Loss: 0.440   lengthscale: 18.039   noise: 0.001
# Iter 476/500 - Loss: 0.440   lengthscale: 18.042   noise: 0.001
# Iter 477/500 - Loss: 0.440   lengthscale: 18.045   noise: 0.001
# Iter 478/500 - Loss: 0.440   lengthscale: 18.048   noise: 0.001
# Iter 479/500 - Loss: 0.440   lengthscale: 18.051   noise: 0.001
# Iter 480/500 - Loss: 0.440   lengthscale: 18.054   noise: 0.001
# Iter 481/500 - Loss: 0.440   lengthscale: 18.057   noise: 0.001
# Iter 482/500 - Loss: 0.440   lengthscale: 18.060   noise: 0.001
# Iter 483/500 - Loss: 0.440   lengthscale: 18.063   noise: 0.001
# Iter 484/500 - Loss: 0.440   lengthscale: 18.066   noise: 0.001
# Iter 485/500 - Loss: 0.440   lengthscale: 18.068   noise: 0.001
# Iter 486/500 - Loss: 0.440   lengthscale: 18.071   noise: 0.001
# Iter 487/500 - Loss: 0.440   lengthscale: 18.074   noise: 0.001
# Iter 488/500 - Loss: 0.440   lengthscale: 18.077   noise: 0.001
# Iter 489/500 - Loss: 0.440   lengthscale: 18.079   noise: 0.001
# Iter 490/500 - Loss: 0.440   lengthscale: 18.082   noise: 0.001
# Iter 491/500 - Loss: 0.440   lengthscale: 18.085   noise: 0.001
# Iter 492/500 - Loss: 0.440   lengthscale: 18.088   noise: 0.001
# Iter 493/500 - Loss: 0.440   lengthscale: 18.090   noise: 0.001
# Iter 494/500 - Loss: 0.440   lengthscale: 18.093   noise: 0.001
# Iter 495/500 - Loss: 0.440   lengthscale: 18.095   noise: 0.001
# Iter 496/500 - Loss: 0.440   lengthscale: 18.098   noise: 0.001
# Iter 497/500 - Loss: 0.440   lengthscale: 18.101   noise: 0.001
# Iter 498/500 - Loss: 0.440   lengthscale: 18.103   noise: 0.001
# Iter 499/500 - Loss: 0.440   lengthscale: 18.106   noise: 0.001
# Iter 500/500 - Loss: 0.440   lengthscale: 18.108   noise: 0.001

# %% [markdown]
# Now, we test predictions. For simplicity, we will assume a fixed variance of $0.01.$

# %%
# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
with torch.no_grad(), qpytorch.settings.fast_pred_var():
    test_x = torch.linspace(0, 1, 51)
    test_x_distributional = torch.stack((test_x, (1e-3 * torch.ones_like(test_x)).log()), dim=1)
    observed_pred = likelihood(model(test_x_distributional))

with torch.no_grad():
    # Initialize plot
    f, ax = plt.subplots(1, 1, figsize=(8, 3))

    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region(rescale=True)
    # Plot training data as black stars
    ax.errorbar(train_x_mean.numpy(), train_y.numpy(), xerr=train_x_stdv, fmt='k*')
    # Plot predictive means as blue line
    ax.plot(test_x.numpy(), observed_pred.mean.numpy(), 'b')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_x.numpy(), lower.numpy(), upper.numpy(), alpha=0.5)
    ax.set_ylim([-3, 3])
    ax.legend(['Observed Data', 'Mean', 'Confidence'])

# %% [markdown]
# As a final note, we've made it very easy to extend the distributional kernel class by exposing a generic `DistributionalInputKernel` class that takes as input any distance function over probability distributions.
